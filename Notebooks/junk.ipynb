# %% [markdown]
# ## Investigating a Pontential Unique Customer Dataset
#
# 1. Checking for unique cities/states across duplicated customers (``customer_unique_id``) shows that locational data remains consistent for ```customer_unique_ids```

# %%
from src.utils import duplication_check

duplication_check(customers, "customer_unique_id", "customer_id", x = "customer_city", y = "customer_state")
# Out:
#                                   duplicate_count  unique_x  unique_y
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455               17         1         1
# 3e43e6105506432c953e165fb2acf44c                9         1         1
# 1b6c7548a2a1f9037c1fd3ddfed95f33                7         1         1
# 6469f99c1f9dfae7733b25662e7f1782                7         1         1
# ca77025e7201e3b30c44b472ff346268                7         1         1
# 63cfc61cee11cbe306bff5857d00bfe4                6         1         1
# 47c1a3033b8b77b3ab6e109eb4d5fdf3                6         1         1
# 12f5d6e1cbf93dafd9dcc19095df0b3d                6         1         1
# de34b16117594161a6a89c50b289d35a                6         1         1
# dc813062e0fc23409cd255f7f53c7074                6         1         1
